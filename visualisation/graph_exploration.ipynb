# %%
import networkx as nx

# %%
# Load the graph from GraphML file
G = nx.read_graphml('../workspace/output/graph.graphml')

# %%
connected_nodes = list(G.neighbors('DB00773'))
print(connected_nodes)
# Out:
# ['P11388', 'TOPOSOMERASE II', 'B-CELL PRECURSOR ACUTE LYMPHOBLASTIC LEUKEMIA', 'TOP2Β', 'TOPOISOMERASE II']
